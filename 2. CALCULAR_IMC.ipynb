# %%
# calculo IMC

def calcular_imc (kg, m):
    
    imc = kg/(m**2)

    if imc < 18.5:
        return("Bajo peso") # un return siempre devuelve una tupla, salvo que diga lo contrario
    elif imc >= 18.5 and imc < 25:
        return("Normal")
    elif imc >=25 and imc < 30:
        return("Sobrepeso")
    else:
        return ("obesidad")
    


# IndiceMasaCorporal = calcular_imc(80,1.80)

# asi no se muestra, se mostraria en el programa. Está bien.
# para que se muestre aqui (y podamos comprobar) se hace un print

# print (calcular_imc(80,180))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 25
#      14         return ("obesidad")
#      18 # IndiceMasaCorporal = calcular_imc(80,1.80)
#      19
#      20 # asi no se muestra, se mostraria en el programa. Está bien.
#      21 # para que se muestre aqui (y podamos comprobar) se hace un print
#      22
#      23 # print (calcular_imc(80,180))
# ---> 25 print (f"Tiene un IMC {tipo} con un valor de {valor:.2f}")
#
# NameError: name 'tipo' is not defined

# %%
kg= int(input("Indica su peso "))
m= float(input("Indica ahora su altura en "))

print(imc)
