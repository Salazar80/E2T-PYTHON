# %%
a = 2

if a < 1:
    print("menor que 1")
if a < 2:
    print("menor que 2")
if a < 3:
    print("menor que 3")
if a < 4:
    print("menor que 4")
if a < 0:
    print("menor que 0")
else:
    print("hola mundo")

# el else va asociado a el ultimo if
# Out:
# menor que 3
# menor que 4
# hola mundo
