# %%
import math # CON ESTO SE PUEDE HACER USO DE TODO EL MODULO

print(math.sqrt(100))
# Out:
# 10.0

# %%
# otra forma de importar el modulo math. Si solo precisa esta funcion, esta seria mas rapida. Solo podria utilizar la funcion de la raiz cuadrada (sqrt)

from math import sqrt

print(math.sqrt(100))
# Out:
# 10.0

# %%
# tambien puedo hacerlo asi

from math import *

print(math.sqrt(100))
